# %%
import numpy as np
import os
import matplotlib.pyplot as plt

def log_RegretMean_plot(res,fstar,label,color,linestyle,error_bound=True):
    
    
    total_record = (np.array(res)-fstar)
    

    N = total_record.shape[0]
    
    std = np.std(total_record,axis=0)
    
    mean = np.mean(total_record,axis=0)
    
    iter = np.array(range(mean.shape[0]))
    
    lower = mean - 1*std/np.sqrt(N)
    upper = mean + 1*std/np.sqrt(N)
    
    lower.astype(float)
    upper.astype(float)
    
    
    plt.plot(mean,linewidth=2,label=label,color=color,linestyle=linestyle)
    if error_bound:
        plt.fill_between(iter, lower, upper,alpha=0.25,color=color)
    
    #plt.yscale("log")  
    
def log_RegretMedian_plot(res,fstar,label,color,linestyle,error_bound=True):
    
    
    total_record = (np.array(res)-fstar)
    
    N = total_record.shape[0]
    
    std = np.std(total_record,axis=0)
    
    mean = np.mean(total_record,axis=0)
    
    iter = np.array(range(mean.shape[0]))
    
    median = np.median(total_record, axis=0)
    
    lower = mean - 1*std/np.sqrt(N)
    upper = mean + 1*std/np.sqrt(N)
    
    lower.astype(float)
    upper.astype(float)
    
    
    plt.plot(median,linewidth=2,label=label,color=color,linestyle=linestyle)
    if error_bound:
        plt.fill_between(iter, lower, upper,alpha=0.25,color=color)
    
    #plt.yscale("log")

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rosenbrock2D_SLogGP(boundary)+logEI'), delimiter=',')



fstar =  0.


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)

# log_RegretMedian_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=False)
# log_RegretMedian_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=False)

plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('Rosenbrock2D')
# Out:
# Text(0.5, 1.0, 'Rosenbrock2D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Ackley2D_SLogGP(boundary)+logEI'), delimiter=',')



N = 100
fstar = 0.


log_RegretMean_plot(SLogGP_logEI[:20],fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI[:20],fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)


plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('Ackley2D')
# Out:
# Text(0.5, 1.0, 'Ackley2D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_SLogGP(boundary)+logEI'), delimiter=',')



fstar = 0.397887


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)

# log_RegretMedian_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=False)
# log_RegretMedian_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=False)

plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('Branin2D')
# Out:
# Text(0.5, 1.0, 'Branin2D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_SLogGP(boundary)+logEI'), delimiter=',')



fstar = 0.


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)

# log_RegretMedian_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=False)
# log_RegretMedian_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=False)

plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('Beale 2D')
# Out:
# Text(0.5, 1.0, 'Beale 2D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_SLogGP(boundary)+logEI'), delimiter=',')



fstar = -1.0317


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)

# log_RegretMedian_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=False)
# log_RegretMedian_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=False)

plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('SixHumpCamel 2D')
# Out:
# Text(0.5, 1.0, 'SixHumpCamel 2D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice2D_SLogGP(boundary)+logEI'), delimiter=',')



fstar = 0.


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)

# log_RegretMedian_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=False)
# log_RegretMedian_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=False)

plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('DixonPrice 2D')
# Out:
# Text(0.5, 1.0, 'DixonPrice 2D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_SLogGP(boundary)+logEI'), delimiter=',')


fstar = 0.


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='logEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='logEI*',color='green',linestyle='-',error_bound=True)

plt.yscale("log") 

plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()

plt.title('Push 4D')
# Out:
# Text(0.5, 1.0, 'Push 4D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP(boundary)+logEI'), delimiter=',')
# SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP(boundary)+logTEI'), delimiter=',')



N = 100
fstar = 0.


log_RegretMean_plot(100-SLogGP_logEI,fstar=fstar,label='$SlogGP+logEI$',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(100-SLogGP_boundary_logEI,fstar=fstar,label='$SlogGP^b+logEI$',color='green',linestyle='-',error_bound=True)
# log_RegretMean_plot(100-SLogGP_boundary_logTEI,fstar=fstar,label='$SlogGP^b+logTEI$',color='black',linestyle='-',error_bound=True)



plt.xlabel('iteration')
plt.ylabel('regret')

plt.grid()

plt.legend()
plt.title('Skin 6D')
# Out:
# Text(0.5, 1.0, 'Skin 6D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'bank_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'bank_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'bank_SLogGP(boundary)+logEI'), delimiter=',')
# SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP(boundary)+logTEI'), delimiter=',')



N = 100
fstar = 0.

log_RegretMean_plot(100-BO_EI[:20],fstar=fstar,label='$GP+EI$',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(100-SLogGP_logEI,fstar=fstar,label='$SlogGP+logEI$',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(100-SLogGP_boundary_logEI,fstar=fstar,label='$SlogGP^b+logEI$',color='green',linestyle='-',error_bound=True)
# log_RegretMean_plot(100-SLogGP_boundary_logTEI,fstar=fstar,label='$SlogGP^b+logTEI$',color='black',linestyle='-',error_bound=True)



plt.xlabel('iteration')
plt.ylabel('regret')

plt.grid()

plt.legend()
plt.title('Bank 6D')
# Out:
# Text(0.5, 1.0, 'Bank 6D')

# %%
BO_EI[:,-1]
# Out:
# array([1.94694052, 2.18820974, 1.62042066, 2.18788058, 2.43046641,
#        5.83522596, 2.35114052, 2.43309963, 3.24117047, 2.34949475,
#        2.26885224, 1.6200915 , 3.64767453, 2.18689312, 2.10756723,
#        2.83598302, 1.86399394, 1.86531056, 2.43013726, 1.5401073 ,
#        2.27115631, 2.83499556, 3.0795563 , 2.5947138 , 2.67338139,
#        2.99825549, 1.9449656 , 2.18722228, 3.72667127, 2.10559231,
#        1.70303808, 2.34883644, 2.51110892, 2.83565386, 2.02527896,
#        1.78302228, 2.67338139, 2.67502716, 3.48474375, 2.02527896,
#        2.43112472, 2.10690892, 4.21546361, 2.35015306, 2.51242553,
#        2.91695468, 2.02593726, 2.43013726, 2.10690892, 2.26885224])

# %%
SLogGP_boundary_logEI[:,-1]
# Out:
# array([1.94628222, 2.35114052, 1.539449  , 2.10723808, 3.40245548,
#        5.91553932, 2.51341299, 2.43244133, 5.02419275, 2.51143807,
#        2.67338139, 1.86300648, 4.78029031, 2.18788058, 2.10756723,
#        4.78226523, 3.56538626, 2.02725388, 1.94364899, 1.70172147])

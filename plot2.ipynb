# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
def log_RegretMean_plot(res,fstar,label,color,linestyle,error_bound=True):
    
    
    total_record = (np.array(res)-fstar)
    
    
    N = total_record.shape[0]
    
    std = np.std(total_record,axis=0)
    
    mean = np.mean(total_record,axis=0)
    
    median = np.median(total_record,axis=0)
    
    iter = np.array(range(mean.shape[0]))
    
    lower = mean - 1*std/np.sqrt(N)
    upper = mean + 1*std/np.sqrt(N)
    
    lower.astype(float)
    upper.astype(float)
    
    
    plt.plot(mean,linewidth=2,label=label,color=color,linestyle=linestyle)
    if error_bound:
        plt.fill_between(iter, lower, upper,alpha=0.25,color=color)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,15))
#plot 1:
plt.subplot(3, 3, 1)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_GP+TEI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/Branin2D_GP+KG'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'final_res2/Branin2D_SLogGP(boundary)+logTEI'), delimiter=',')



fstar = 0.397887

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
plt.ylabel('regret')

plt.grid()

plt.yscale("log") 
#plt.legend()
plt.title('Branin 2D')




#plot 2:
plt.subplot(3, 3, 2)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_GP+TEI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/Beale2D_GP+KG'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

# plt.legend()
plt.title('Beale 2D')

plt.subplot(3, 3, 3)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_GP+TEI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/SixHumpCamel2D_GP+KG'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = -1.0317


log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
# plt.ylabel('regret')

plt.grid()
plt.yscale("log") 

#plt.legend()
plt.title('SixHumpCamel 2D')

plt.subplot(3, 3, 4)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_GP+TEI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/Hartmann3D_GP+KG'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = -3.86278

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

#plt.legend()
plt.title('Hartmann 3D')

plt.subplot(3, 3, 5)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_GP+TEI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/DixonPrice4D_GP+KG'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

# plt.legend()
plt.title('DixonPrice 4D')

plt.subplot(3, 3, 6)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_GP+EI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/Rosenbrock5D_GP+KG'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'final_res2/Rosenbrock5D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.


log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')

plt.grid()

plt.yscale("log") 
# plt.legend()
plt.title('Rosenbrock 5D')


plt.subplot(3, 3, 7)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_GP+EI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/Ackley6D_GP+KG'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'final_res2/Ackley6D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
plt.ylabel('regret')

plt.grid()

#plt.yscale("log") 
#plt.legend()
plt.title('Ackley 6D')


plt.subplot(3, 3, 8)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_GP+EI'), delimiter=',')
BO_KG = np.genfromtxt(os.path.join(os.getcwd(),'KG/Powell8D_GP+KG'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

# plt.xlabel('iteration')
# plt.ylabel('regret')

plt.xlabel('iteration')
# plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

# plt.legend()
plt.title('Powell 8D')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=False, ncol=3,fontsize=20)

plt.subplot(3, 3, 9)
Random = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_transformedGP+ERM'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =-10*39.166166 

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(-BO_KG,fstar=fstar,label='GP+KG',color='olive',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='GP+TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='GP+MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='parabolic GP+ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
#plt.legend()
plt.title('StyblinskiTang 10D')

plt.savefig('synthetic function results.pdf',format='pdf',bbox_inches='tight', pad_inches=0.1)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,15))
#plot 1:
plt.subplot(3, 3, 1)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Branin2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.397887

log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')

plt.grid()

plt.yscale("log") 
#plt.legend()
plt.title('Branin 2D')




#plot 2:
plt.subplot(3, 3, 2)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Beale2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
#plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

#plt.legend()
plt.title('Beale 2D')


plt.subplot(3, 3, 3)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/SixHumpCamel2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = -1.0317


log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')

plt.grid()
plt.yscale("log") 

# plt.legend()
plt.title('SixHumpCamel 2D')


plt.subplot(3, 3, 4)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Hartmann3D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =  -3.86278

log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

# plt.legend()
plt.title('Hartmann 3D')

plt.subplot(3, 3, 5)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/DixonPrice4D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =  0.

log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
# plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

#plt.legend()
plt.title('DixonPrice 4D')

plt.subplot(3, 3, 6)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Rosenbrock5D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
plt.ylabel('regret')

plt.grid()

plt.yscale("log") 
#plt.legend()
plt.title('Rosenbrock 5D')


plt.subplot(3, 3, 7)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Ackley6D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.


log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
plt.ylabel('regret')

plt.grid()

plt.yscale("log") 
#plt.legend()
plt.title('Ackley 6D')


plt.subplot(3, 3, 8)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/Powell8D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =  0.


log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
# plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

# plt.legend()
plt.title('Powell 8D')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=False, ncol=3,fontsize=20)

plt.subplot(3, 3, 9)
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_SLogGP+logEI'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Result/StyblinskiTang10D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = -10*39.166166 


log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed $\hat{C}$)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)


plt.xlabel('iteration')
# plt.ylabel('regret')
plt.yscale("log") 
plt.grid()

#plt.legend()
plt.title('StyblinskiTang 10D')

plt.savefig('synthetic function different components.pdf',format='pdf',bbox_inches='tight', pad_inches=0.1)

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
def log_RegretMean_plot(res,fstar,label,color,linestyle,error_bound=True):
    
    
    total_record = (np.array(res)-fstar)
    
    
    N = total_record.shape[0]
    
    std = np.std(total_record,axis=0)
    
    mean = np.mean(total_record,axis=0)
    
    median = np.median(total_record,axis=0)
    
    iter = np.array(range(mean.shape[0]))
    
    lower = mean - 1*std/np.sqrt(N)
    upper = mean + 1*std/np.sqrt(N)
    
    lower.astype(float)
    upper.astype(float)
    
    
    plt.plot(mean,linewidth=2,label=label,color=color,linestyle=linestyle)
    if error_bound:
        plt.fill_between(iter, lower, upper,alpha=0.25,color=color)

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Push4D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Push 4D')
# Out:
# Text(0.5, 1.0, 'Push 4D')

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'skin_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'skin_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'skin_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'skin_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'skin_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(100-Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(100-BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(100-BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(100-BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(100-BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(100-SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(100-SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(100-SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(100-SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
plt.ylabel('accuracy')


# plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('skin 6D')
# Out:
# Text(0.5, 1.0, 'skin 6D')

# %%
# BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_original8D_GP+EI'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_original8D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_original8D_SLogGP(boundary)+logEI'), delimiter=',')

fstar = 0.

# log_RegretMean_plot(BO_EI,fstar=fstar,label='GP+EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP+SlogEI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP$^b$+SlogEI',color='green',linestyle='-',error_bound=True)

#log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)
plt.xlabel('iteration')
plt.ylabel('regret')
#plt.yscale("log") 
plt.grid()

plt.legend()
plt.title('Roverr original 8D')
# Out:
# Text(0.5, 1.0, 'Roverr original 8D')

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Beale2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Beale 2D')
# Out:
# Text(0.5, 1.0, 'Beale 2D')

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Branin2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar = 0.397887

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Branin 2D')
# Out:
# Text(0.5, 1.0, 'Branin 2D')

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'SixHumpCamel2D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =  -1.0317

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('SixHumpCamel 2D')
# Out:
# Text(0.5, 1.0, 'SixHumpCamel 2D')

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'Hartmann3D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =   -3.86278

# log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
# log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
# log_RegretMean_plot(BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
# log_RegretMean_plot(BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
# log_RegretMean_plot(BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Hartmann 3D')
# Out:
# Text(0.5, 1.0, 'Hartmann 3D')

# %%
Random = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_Random'), delimiter=',')
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_GP+EI'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_GP+TEI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_GP+MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_transformedGP+ERM'), delimiter=',')
SLogGP_logEI_fixedC = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_SLogGP+logEI_fixedC'), delimiter=',')
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_SLogGP(boundary)+logEI'), delimiter=',')
SLogGP_boundary_logTEI = np.genfromtxt(os.path.join(os.getcwd(),'DixonPrice4D_SLogGP(boundary)+logTEI'), delimiter=',')


fstar =  0.

log_RegretMean_plot(Random,fstar=fstar,label='Random',color='grey',linestyle='dotted',error_bound=True)
log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)
log_RegretMean_plot(BO_TEI,fstar=fstar,label='TEI',color='darkviolet',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_MES,fstar=fstar,label='MES$^b$',color='yellow',linestyle='-',error_bound=True)
log_RegretMean_plot(BO_ERM,fstar=fstar,label='ERM',color='orange',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_logEI_fixedC,fstar=fstar,label='SlogGP+SlogEI (fixed C)',color='peru',linestyle='dashed',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)
log_RegretMean_plot(SLogGP_boundary_logTEI,fstar=fstar,label='SlogGP$^b$+SlogTEI',color='black',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('DixonPrice 4D')
# Out:
# Text(0.5, 1.0, 'DixonPrice 4D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_smooth8D_GP+EI'), delimiter=',')


SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_smooth8D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_smooth8D_SLogGP(boundary)+logEI'), delimiter=',')


fstar =  0.


log_RegretMean_plot(BO_EI,fstar=fstar,label='EI',color='blue',linestyle='dashed',error_bound=True)

log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)

log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Rover 8D')
# Out:
# Text(0.5, 1.0, 'Rover 8D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_smooth8D2_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_smooth8D2_SLogGP(boundary)+logEI'), delimiter=',')


fstar =  0.


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)

log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Rover 8D')
# Out:
# Text(0.5, 1.0, 'Rover 8D')

# %%
SLogGP_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_8D_SLogGP+logEI'), delimiter=',')
SLogGP_boundary_logEI = np.genfromtxt(os.path.join(os.getcwd(),'Rover_8D_SLogGP(boundary)+logEI'), delimiter=',')


fstar =  0.


log_RegretMean_plot(SLogGP_logEI,fstar=fstar,label='SlogGP EI',color='red',linestyle='dashed',error_bound=True)

log_RegretMean_plot(SLogGP_boundary_logEI,fstar=fstar,label='SlogGP EI (boundary)',color='green',linestyle='-',error_bound=True)

plt.xlabel('iteration')
# plt.ylabel('regret')


#plt.yscale("log") 
plt.grid()
plt.legend()
plt.title('Rover 8D')
# Out:
# Text(0.5, 1.0, 'Rover 8D')
